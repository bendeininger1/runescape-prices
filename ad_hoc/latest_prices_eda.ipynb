# %%
from pyspark.sql.functions import *

# %%
df = spark.read.table("runescape.02_silver.latest_prices_enriched").filter(col("price")< 10000)

# %%
# %skip
df2 = df.filter(col("limit") > 100)
df2 = df2.filter(col("members")=="false")
df2.display()

# %%
# %skip
df3 = df.filter("id IN ('1731','1725','1317','1121','1073','1315','1161','1199') AND time >'1768419654'")
df3.display()

# %%
df3 = df.filter("id IN ('1731') AND time >'1768419654'")
df3.display()

# %%
# Read data from 'runescape.01_bronze.1h_prices' to get Volumes
df = spark.read.table("runescape.01_bronze.1h_prices")
# Filter to only use the most recent Volume data


df.display()

# %%
df.filter("time = 1770062400").count()

# %%
df.filter("time = 1769706000").count()

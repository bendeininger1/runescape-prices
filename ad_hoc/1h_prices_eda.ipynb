# %%
import pyspark.sql.functions as sf
from time import time
spark.conf.set("spark.sql.session.timeZone", "America/New_York")

# %%
# How mmuch time should be analyzed in seconds
window_time = time() - 10000000

# %%
# Read data from 'runescape.02_silver.item_mapping'
df_map = spark.read.table("runescape.02_silver.item_mapping")

# %%
# Read data from 'runescape.01_bronze.1h_prices' to get Volumes
df_1hour = spark.read.table("runescape.01_bronze.1h_prices")
# Filter to only use the most recent Volume data
df_1hour = df_1hour.filter(f"time >= {window_time}")
df_1hour = df_1hour.join(df_map,"id")
df_1hour = df_1hour.sort("time")
#df_1hour = df_1hour.withColumn("profit", sf.round((sf.col("highalch") - sf.col("avg_price")) - 100,1))

# %%
#
df_1hour_irit = df_1hour.filter("ID IN ('259','227','101')")
df_1hour_irit.display()
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
irit_leaf = 2686
vial_of_water = 5
irit_potion_unf_sale = 2870
fee_percent = .98
irit_potion_unf_sale_rev = fee_percent * irit_potion_unf_sale
profit = irit_potion_unf_sale_rev - irit_leaf - vial_of_water
profit = round(profit,2)
print(profit)

#time_to_make = 
items_per_hour = 4100 #aprox from the wiki
profit_per_hour = profit * items_per_hour
print(profit_per_hour)

# %%
df_1hour.display()
df_1hour.count()
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
df_1hour_filtered_high = df_1hour.filter("avg1HourHighVolume > 25")
df_1hour_filtered_high.count()

# %%
df_1hour_filtered_low = df_1hour.filter("avg1HourLowVolume > 25")
df_1hour_filtered_low.count()

# %%
# aggregate table
df_1hour_agg = df_1hour.groupBy("name").avg('avg1HourHighVolume', 'avg1HourLowVolume')
df_1hour_agg.display()

# %%
df_1hour_count = df_1hour.groupBy("name").count()
df_1hour_count.display()

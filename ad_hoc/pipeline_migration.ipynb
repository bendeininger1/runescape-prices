-- %% [markdown]
-- This notebook updates the streaming table's pipelineid to the new pipelineid
-- This needs to be run when a creating a new databricks workspace
-- This notebook must be run in the old workspace
-- Update the pipelineID with the new pipelineID before running.
-- I think the dp.create_sink() function in the pipeline file latest_prices_raw_stream.py needs
-- to be commented out for this command to run?
--
-- https://docs.databricks.com/aws/en/ldp/move-table

-- %%
--update the pipeline id to migrate to a new workspace
ALTER STREAMING TABLE runescape.01_bronze.latest_prices_raw_stream
  SET TBLPROPERTIES("pipelines.pipelineId"="97a1e8b0-fdac-4c8d-8fb1-d95fa114d878");

-- %% [markdown]
-- This notebook creates the 3 data catalogs for prod, dev, and test.
-- It also creates the schemas and voulmes.

-- %%
CREATE CATALOG IF NOT EXISTS runescape_prod
MANAGED LOCATION 'abfss://external-data@externalstorage1235653.dfs.core.windows.net/rs_prod'

-- %%
CREATE CATALOG IF NOT EXISTS runescape_dev
MANAGED LOCATION 'abfss://external-data@externalstorage1235653.dfs.core.windows.net/rs_dev'

-- %%
CREATE CATALOG IF NOT EXISTS runescape_test
MANAGED LOCATION 'abfss://external-data@externalstorage1235653.dfs.core.windows.net/rs_test'

-- %%
CREATE SCHEMA IF NOT EXISTS runescape_prod.00_landing;
CREATE SCHEMA IF NOT EXISTS runescape_prod.01_bronze;
CREATE SCHEMA IF NOT EXISTS runescape_prod.02_silver;
CREATE SCHEMA IF NOT EXISTS runescape_prod.03_gold;

-- %%
CREATE SCHEMA IF NOT EXISTS runescape_dev.00_landing;
CREATE SCHEMA IF NOT EXISTS runescape_dev.01_bronze;
CREATE SCHEMA IF NOT EXISTS runescape_dev.02_silver;
CREATE SCHEMA IF NOT EXISTS runescape_dev.03_gold;

-- %%
CREATE SCHEMA IF NOT EXISTS runescape_test.00_landing;
CREATE SCHEMA IF NOT EXISTS runescape_test.01_bronze;
CREATE SCHEMA IF NOT EXISTS runescape_test.02_silver;
CREATE SCHEMA IF NOT EXISTS runescape_test.03_gold;

-- %%
CREATE VOLUME IF NOT EXISTS runescape_prod.00_landing.data_sources

-- %%
CREATE VOLUME IF NOT EXISTS runescape_dev.00_landing.data_sources

-- %%
CREATE VOLUME IF NOT EXISTS runescape_test.00_landing.data_sources
